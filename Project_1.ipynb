# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Ryan Sung Hwa Chung
# * Student pace: Part Time
# * Scheduled project review date/time: 6/5/2021
# * Instructor name: Yish
# * Blog post URL:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import seaborn as sns

# %% [markdown]
# # Importing Data Sets 1-4

# %%
movies_df = pd.read_csv('C://Users//rychu//Documents//Flatiron//Phase-1-Project-Docs//zippedData//bom.movie_gross.csv')
title_df = pd.read_csv('C://Users//rychu//Documents//Flatiron//Phase-1-Project-Docs//zippedData//imdb.title.basics.csv')
ratings_df = pd.read_csv('C://Users//rychu//Documents//Flatiron//Phase-1-Project-Docs//zippedData//imdb.title.ratings.csv')
crew_df = pd.read_csv('C://Users//rychu//Documents//Flatiron//Phase-1-Project-Docs//zippedData//imdb.title.crew.csv')

# %%
movies_df.info()
title_df.info()
ratings_df.info()
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
display(movies_df.head())
movies_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
display(title_df.head())
title_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
display(ratings_df.head())
ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
display(crew_df.head())
crew_df.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
display(movies_df.describe())
movies_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
display(title_df.describe())
title_df.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
display(ratings_df.describe())
ratings_df.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
display(crew_df.describe())
crew_df.describe()
# Out:
#            tconst  directors    writers
# count      146144     140417     110261
# unique     146144      98525      91920
# top     tt3450190  nm3266654  nm0000636
# freq            1         62         80
#            tconst  directors    writers
# count      146144     140417     110261
# unique     146144      98525      91920
# top     tt3450190  nm3266654  nm0000636
# freq            1         62         80

# %% [markdown]
# # Cleaning 1st Dataframe

# %%
movies_df.isna().any()
# Out:
# title             False
# studio             True
# domestic_gross     True
# foreign_gross      True
# year              False
# dtype: bool

# %%
movies_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
movies_df = movies_df.drop('foreign_gross', axis = 1)

# %%
movies_df.isna().sum()
# Out:
# title              0
# studio             5
# domestic_gross    28
# year               0
# dtype: int64

# %%
mean_domestic_gross = movies_df['domestic_gross'].mean()
movies_df['domestic_gross'].fillna(mean_domestic_gross, inplace=True)
movies_df.isna().sum()
# Out:
# title             0
# studio            5
# domestic_gross    0
# year              0
# dtype: int64

# %%
movies_df['studio'].fillna(value="N/A", inplace=True)
movies_df.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# year              0
# dtype: int64

# %%
movies_df.isna().any().any()
# Out:
# False

# %%
movies_df.drop_duplicates(subset='title', inplace=True)
movies_df.reset_index(drop=True, inplace=True)

# %%
movies_df.info()
movies_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3386 entries, 0 to 3385
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3386 non-null   object
#  1   studio          3386 non-null   object
#  2   domestic_gross  3386 non-null   float64
#  3   year            3386 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 105.9+ KB
#                                          title studio  domestic_gross  year
# 0                                  Toy Story 3     BV     415000000.0  2010
# 1                   Alice in Wonderland (2010)     BV     334200000.0  2010
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0  2010
# 3                                    Inception     WB     292600000.0  2010
# 4                          Shrek Forever After   P/DW     238700000.0  2010

# %%
movies_df = movies_df.astype({'title': object, 'studio': object, 'domestic_gross': int, 'year': int })

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3386 entries, 0 to 3385
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3386 non-null   object
#  1   studio          3386 non-null   object
#  2   domestic_gross  3386 non-null   int32
#  3   year            3386 non-null   int32
# dtypes: int32(2), object(2)
# memory usage: 79.5+ KB

# %% [markdown]
# # Cleaning 2nd Dataframe

# %%
title_df.isna().any()
# Out:
# tconst             False
# primary_title      False
# original_title      True
# start_year         False
# runtime_minutes     True
# genres              True
# dtype: bool

# %%
title_df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
title_df = title_df.drop('genres', axis = 1)

# %%
title_df['original_title'].fillna(value="N/A", inplace=True)

# %%
mean_runtime_minutes = title_df['runtime_minutes'].mean()
title_df['runtime_minutes'].fillna(mean_runtime_minutes, inplace=True)
title_df.isna().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# dtype: int64

# %%
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146144 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  146144 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.6+ MB

# %%
title_df = title_df.astype({'tconst': object, 'primary_title': object, 'original_title': object, 'start_year': object, 'runtime_minutes': int})

# %%
title_df.drop_duplicates(subset='tconst', inplace=True)
title_df.reset_index(drop=True, inplace=True)

# %%
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146144 non-null  object
#  3   start_year       146144 non-null  object
#  4   runtime_minutes  146144 non-null  int32
# dtypes: int32(1), object(4)
# memory usage: 5.0+ MB

# %% [markdown]
# # Cleaning 3rd Dataframe

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
ratings_df.isna().any()
# Out:
# tconst           False
# averagerating    False
# numvotes         False
# dtype: bool

# %%
ratings_df.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
ratings_df.drop_duplicates(subset='tconst', inplace=True)
ratings_df.reset_index(drop=True, inplace=True)

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# # Cleaning 4th Data Set

# %%
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
crew_df.isna().any()
# Out:
# tconst       False
# directors     True
# writers       True
# dtype: bool

# %%
crew_df.isna().sum()
# Out:
# tconst           0
# directors     5727
# writers      35883
# dtype: int64

# %%
crew_df['directors'].fillna(value="N/A", inplace=True)
crew_df['writers'].fillna(value="N/A", inplace=True)

# %%
crew_df.isna().sum()
# Out:
# tconst       0
# directors    0
# writers      0
# dtype: int64

# %%
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  146144 non-null  object
#  2   writers    146144 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
crew_df.drop_duplicates(subset='tconst', inplace=True)
crew_df.reset_index(drop=True, inplace=True)
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  146144 non-null  object
#  2   writers    146144 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# # Merging DFs 1-4

# %%
movies_df.info()
title_df.info()
ratings_df.info()
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3386 entries, 0 to 3385
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3386 non-null   object
#  1   studio          3386 non-null   object
#  2   domestic_gross  3386 non-null   int32
#  3   year            3386 non-null   int32
# dtypes: int32(2), object(2)
# memory usage: 79.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146144 non-null  object
#  3   start_year       146144 non-null  object
#  4   runtime_minutes  146144 non-null  int32
# dtypes: int32(1), object(4)
# memory usage: 5.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  146144 non-null  object
#  2   writers    146144 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
# Merge 4 to 2, then 4+2 to 3, then to 1

# %%
df_4_2 = title_df.merge(crew_df, how = "inner", on = "tconst")
df_4_2.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#   start_year  runtime_minutes            directors  \
# 0       2013              175            nm0712540
# 1       2019              114            nm0002411
# 2       2018              122            nm0000080
# 3       2018               86            nm0611531
# 4       2017               80  nm0765384,nm0749914
#
#                                    writers
# 0  nm0023551,nm1194313,nm0347899,nm1391276
# 1                                      N/A
# 2                      nm0000080,nm0462648
# 3                                nm0347899
# 4                      nm1360635,nm0749914

# %%
df_4_2.isna().any()
df_4_2.isna().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# directors          0
# writers            0
# dtype: int64

# %%
df_4_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146144 non-null  object
#  3   start_year       146144 non-null  object
#  4   runtime_minutes  146144 non-null  int32
#  5   directors        146144 non-null  object
#  6   writers          146144 non-null  object
# dtypes: int32(1), object(6)
# memory usage: 8.4+ MB

# %%
df_432 = ratings_df.merge(df_4_2, how = "inner", on = "tconst")

# %%
df_432.info()
df_432.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   averagerating    73856 non-null  float64
#  2   numvotes         73856 non-null  int64
#  3   primary_title    73856 non-null  object
#  4   original_title   73856 non-null  object
#  5   start_year       73856 non-null  object
#  6   runtime_minutes  73856 non-null  int32
#  7   directors        73856 non-null  object
#  8   writers          73856 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(6)
# memory usage: 5.4+ MB
#         tconst  averagerating  numvotes                    primary_title  \
# 0   tt10356526            8.3        31                 Laiye Je Yaarian
# 1   tt10384606            8.9       559                       Borderless
# 2    tt1042974            6.4        20                        Just Inès
# 3    tt1043726            4.2     50352           The Legend of Hercules
# 4    tt1060240            6.5        21                        Até Onde?
# 5    tt1069246            6.2       326                       Habana Eva
# 6    tt1094666            7.0      1613                       The Hammer
# 7    tt1130982            6.4       571                  The Night Clerk
# 8    tt1156528            7.2       265                    Silent Sonata
# 9    tt1161457            4.2       148                       Vanquisher
# 10   tt1171222            5.1      8296                    Baggage Claim
# 11   tt1174693            5.8      2381              The Four-Faced Liar
# 12   tt1181840            7.0      5494  Jack and the Cuckoo-Clock Heart
# 13   tt1193623            8.0         5                   Buried Prayers
# 14   tt1199588            5.5        74                      Black Widow
#
#                    original_title start_year  runtime_minutes  \
# 0                Laiye Je Yaarian       2019              117
# 1                      Borderless       2019               87
# 2                       Just Inès       2010               90
# 3          The Legend of Hercules       2014               99
# 4                       Até Onde?       2011               73
# 5                      Habana Eva       2010              106
# 6                          Hamill       2010              108
# 7                    Avant l'aube       2011              104
# 8              Circus Fantasticus       2011               77
# 9                  The Vanquisher       2016               90
# 10                  Baggage Claim       2013               96
# 11            The Four-Faced Liar       2010               87
# 12  Jack et la mécanique du coeur       2013               94
# 13                 Buried Prayers       2010               86
# 14                    Black Widow       2010               75
#
#               directors                                  writers
# 0             nm8353804                      nm3057599,nm4179342
# 1   nm9932562,nm9250842                                      N/A
# 2             nm1915232                                nm1915232
# 3             nm0001317  nm0393517,nm0316417,nm0001317,nm1048866
# 4             nm1926349                                nm1926349
# 5             nm0868643  nm2726004,nm0140502,nm1523568,nm0868643
# 6             nm1464150                      nm1670295,nm1559624
# 7             nm1292833                      nm1305724,nm1292833
# 8             nm0121203                                nm0121203
# 9             nm2874896                                nm2874896
# 10            nm0847859                                nm0847859
# 11            nm0153774                                nm2903680
# 12  nm0540962,nm1071849                                nm0540962
# 13            nm1746428                      nm0218725,nm0563248
# 14            nm0736402                                nm0736402

# %%
df_432_edited = df_432.rename(columns = {'primary_title': 'title'})

# %%
df_432_edited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   averagerating    73856 non-null  float64
#  2   numvotes         73856 non-null  int64
#  3   title            73856 non-null  object
#  4   original_title   73856 non-null  object
#  5   start_year       73856 non-null  object
#  6   runtime_minutes  73856 non-null  int32
#  7   directors        73856 non-null  object
#  8   writers          73856 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(6)
# memory usage: 5.4+ MB

# %%
df_432_edited.head()
# Out:
#        tconst  averagerating  numvotes                   title  \
# 0  tt10356526            8.3        31        Laiye Je Yaarian
# 1  tt10384606            8.9       559              Borderless
# 2   tt1042974            6.4        20               Just Inès
# 3   tt1043726            4.2     50352  The Legend of Hercules
# 4   tt1060240            6.5        21               Até Onde?
#
#            original_title start_year  runtime_minutes            directors  \
# 0        Laiye Je Yaarian       2019              117            nm8353804
# 1              Borderless       2019               87  nm9932562,nm9250842
# 2               Just Inès       2010               90            nm1915232
# 3  The Legend of Hercules       2014               99            nm0001317
# 4               Até Onde?       2011               73            nm1926349
#
#                                    writers
# 0                      nm3057599,nm4179342
# 1                                      N/A
# 2                                nm1915232
# 3  nm0393517,nm0316417,nm0001317,nm1048866
# 4                                nm1926349

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3386 entries, 0 to 3385
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3386 non-null   object
#  1   studio          3386 non-null   object
#  2   domestic_gross  3386 non-null   int32
#  3   year            3386 non-null   int32
# dtypes: int32(2), object(2)
# memory usage: 79.5+ KB

# %% [markdown]
# # Creating Final Dataframe

# %%
df_1234 = movies_df.merge(df_432_edited, how = "inner", on = "title")

# %%
df_1234.head()
# Out:
#                         title studio  domestic_gross  year     tconst  \
# 0                 Toy Story 3     BV       415000000  2010  tt0435761
# 1                   Inception     WB       292600000  2010  tt1375666
# 2         Shrek Forever After   P/DW       238700000  2010  tt0892791
# 3  The Twilight Saga: Eclipse   Sum.       300500000  2010  tt1325004
# 4                  Iron Man 2   Par.       312400000  2010  tt1228705
#
#    averagerating  numvotes              original_title start_year  \
# 0            8.3    682218                 Toy Story 3       2010
# 1            8.8   1841066                   Inception       2010
# 2            6.3    167532         Shrek Forever After       2010
# 3            5.0    211733  The Twilight Saga: Eclipse       2010
# 4            7.0    657690                  Iron Man 2       2010
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers
# 0            nm0005124,nm0004056,nm0881279,nm1578335
# 1                                          nm0634240
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...
# 3                                nm0742279,nm2769412
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158

# %%
df_1234.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3025 entries, 0 to 3024
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3025 non-null   object
#  1   studio           3025 non-null   object
#  2   domestic_gross   3025 non-null   int32
#  3   year             3025 non-null   int32
#  4   tconst           3025 non-null   object
#  5   averagerating    3025 non-null   float64
#  6   numvotes         3025 non-null   int64
#  7   original_title   3025 non-null   object
#  8   start_year       3025 non-null   object
#  9   runtime_minutes  3025 non-null   int32
#  10  directors        3025 non-null   object
#  11  writers          3025 non-null   object
# dtypes: float64(1), int32(3), int64(1), object(7)
# memory usage: 271.8+ KB

# %%
cleaned_df = df_1234

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3025 entries, 0 to 3024
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3025 non-null   object
#  1   studio           3025 non-null   object
#  2   domestic_gross   3025 non-null   int32
#  3   year             3025 non-null   int32
#  4   tconst           3025 non-null   object
#  5   averagerating    3025 non-null   float64
#  6   numvotes         3025 non-null   int64
#  7   original_title   3025 non-null   object
#  8   start_year       3025 non-null   object
#  9   runtime_minutes  3025 non-null   int32
#  10  directors        3025 non-null   object
#  11  writers          3025 non-null   object
# dtypes: float64(1), int32(3), int64(1), object(7)
# memory usage: 271.8+ KB

# %%
cleaned_df = cleaned_df.set_index('tconst')

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3025 entries, tt0435761 to tt5718046
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3025 non-null   object
#  1   studio           3025 non-null   object
#  2   domestic_gross   3025 non-null   int32
#  3   year             3025 non-null   int32
#  4   averagerating    3025 non-null   float64
#  5   numvotes         3025 non-null   int64
#  6   original_title   3025 non-null   object
#  7   start_year       3025 non-null   object
#  8   runtime_minutes  3025 non-null   int32
#  9   directors        3025 non-null   object
#  10  writers          3025 non-null   object
# dtypes: float64(1), int32(3), int64(1), object(6)
# memory usage: 248.1+ KB

# %%
cleaned_df.isna().any()
# Out:
# title              False
# studio             False
# domestic_gross     False
# year               False
# averagerating      False
# numvotes           False
# original_title     False
# start_year         False
# runtime_minutes    False
# directors          False
# writers            False
# dtype: bool

# %%
cleaned_df.isna().sum()
# Out:
# title              0
# studio             0
# domestic_gross     0
# year               0
# averagerating      0
# numvotes           0
# original_title     0
# start_year         0
# runtime_minutes    0
# directors          0
# writers            0
# dtype: int64

# %%
cleaned_df.head(20)
# Out:
#                                                        title studio  \
# tconst
# tt0435761                                        Toy Story 3     BV
# tt1375666                                          Inception     WB
# tt0892791                                Shrek Forever After   P/DW
# tt1325004                         The Twilight Saga: Eclipse   Sum.
# tt1228705                                         Iron Man 2   Par.
# tt0398286                                            Tangled     BV
# tt1323594                                      Despicable Me   Uni.
# tt0892769                           How to Train Your Dragon   P/DW
# tt0980970  The Chronicles of Narnia: The Voyage of the Da...    Fox
# tt1504320                                  The King's Speech  Wein.
# tt1155076                                     The Karate Kid   Sony
# tt0473075                Prince of Persia: The Sands of Time     BV
# tt0947798                                         Black Swan   FoxS
# tt1001526                                           Megamind   P/DW
# tt6858500                                         Robin Hood   Uni.
# tt2363363                                         Robin Hood   Uni.
# tt4532826                                         Robin Hood   Uni.
# tt0955308                                         Robin Hood   Uni.
# tt0938283                                 The Last Airbender   Par.
# tt0970866                                     Little Fockers   Uni.
#
#            domestic_gross  year  averagerating  numvotes  \
# tconst
# tt0435761       415000000  2010            8.3    682218
# tt1375666       292600000  2010            8.8   1841066
# tt0892791       238700000  2010            6.3    167532
# tt1325004       300500000  2010            5.0    211733
# tt1228705       312400000  2010            7.0    657690
# tt0398286       200800000  2010            7.8    366366
# tt1323594       251500000  2010            7.7    464511
# tt0892769       217600000  2010            8.1    611299
# tt0980970       104400000  2010            6.3    129663
# tt1504320       135500000  2010            8.0    593629
# tt1155076       176600000  2010            6.2    146401
# tt0473075        90800000  2010            6.6    254975
# tt0947798       107000000  2010            8.0    648854
# tt1001526       148400000  2010            7.3    207488
# tt6858500       105300000  2010            7.6         5
# tt2363363       105300000  2010            6.3        78
# tt4532826       105300000  2010            5.3     41588
# tt0955308       105300000  2010            6.6    239480
# tt0938283       131800000  2010            4.1    137734
# tt0970866       148400000  2010            5.5     99222
#
#                                               original_title start_year  \
# tconst
# tt0435761                                        Toy Story 3       2010
# tt1375666                                          Inception       2010
# tt0892791                                Shrek Forever After       2010
# tt1325004                         The Twilight Saga: Eclipse       2010
# tt1228705                                         Iron Man 2       2010
# tt0398286                                            Tangled       2010
# tt1323594                                      Despicable Me       2010
# tt0892769                           How to Train Your Dragon       2010
# tt0980970  The Chronicles of Narnia: The Voyage of the Da...       2010
# tt1504320                                  The King's Speech       2010
# tt1155076                                     The Karate Kid       2010
# tt0473075                Prince of Persia: The Sands of Time       2010
# tt0947798                                         Black Swan       2010
# tt1001526                                           Megamind       2010
# tt6858500                                         Robin Hood       2018
# tt2363363                                         Robin Hood       2013
# tt4532826                                         Robin Hood       2018
# tt0955308                                         Robin Hood       2010
# tt0938283                                 The Last Airbender       2010
# tt0970866                                     Little Fockers       2010
#
#            runtime_minutes            directors  \
# tconst
# tt0435761              103            nm0881279
# tt1375666              148            nm0634240
# tt0892791               93            nm0593610
# tt1325004              124            nm1720541
# tt1228705              124            nm0269463
# tt0398286              100  nm1977355,nm0397174
# tt1323594               95  nm1853544,nm0719208
# tt0892769               98  nm0761498,nm0213450
# tt0980970              113            nm0000776
# tt1504320              118            nm0393799
# tt1155076              140            nm0958969
# tt0473075              116            nm0001565
# tt0947798              108            nm0004716
# tt1001526               95            nm0569891
# tt6858500               86            nm7789892
# tt2363363               92            nm2347483
# tt4532826              116            nm1163264
# tt0955308              140            nm0000631
# tt0938283              103            nm0796117
# tt0970866               98            nm0919369
#
#                                                      writers
# tconst
# tt0435761            nm0005124,nm0004056,nm0881279,nm1578335
# tt1375666                                          nm0634240
# tt0892791  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...
# tt1325004                                nm0742279,nm2769412
# tt1228705  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158
# tt0398286                      nm1557594,nm0342278,nm0342303
# tt1323594                      nm0666791,nm0202425,nm0655053
# tt0892769  nm0204030,nm0213450,nm0761498,nm2441763,nm0405...
# tt0980970            nm1321655,nm1321656,nm0678104,nm0507000
# tt1504320                                          nm0782436
# tt1155076                                nm0614050,nm0436543
# tt0473075            nm0945026,nm1215164,nm0076166,nm0575338
# tt0947798                      nm2114730,nm0374560,nm0572352
# tt1001526                                nm0774786,nm2523794
# tt6858500                                                N/A
# tt2363363                                nm2347483,nm2956784
# tt4532826                                nm9808366,nm3598916
# tt0955308                      nm0001338,nm0717550,nm0903456
# tt0938283                                          nm0796117
# tt0970866            nm0357453,nm0836001,nm0322839,nm0164898

# %% [markdown]
# # Cleaning of 5th Data Set for Additional Info

# %%
budgets_df = pd.read_csv('C://Users//rychu//Documents//Flatiron//dsc-phase-1-project//zippedData//tn.movie_budgets.csv')

# %%
budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets_df.isna().any()
# Out:
# id                   False
# release_date         False
# movie                False
# production_budget    False
# domestic_gross       False
# worldwide_gross      False
# dtype: bool

# %%
budgets_df = budgets_df.drop('id', axis = 1)

# %%
budgets_df.head()
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets_df = budgets_df.rename(columns = {'movie': 'title'})

# %%
budgets_df.head()
# Out:
#    release_date                                        title  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   title              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 226.0+ KB

# %% [markdown]
# # Merging 5th to Final Cleaned DF

# %%
finalcleaned_df = cleaned_df.merge(budgets_df, how = "inner", on = "title")

# %%
finalcleaned_df.head(10)
# Out:
#                                                title studio  domestic_gross_x  \
# 0                                        Toy Story 3     BV         415000000
# 1                                          Inception     WB         292600000
# 2                                Shrek Forever After   P/DW         238700000
# 3                         The Twilight Saga: Eclipse   Sum.         300500000
# 4                                         Iron Man 2   Par.         312400000
# 5                                            Tangled     BV         200800000
# 6                                      Despicable Me   Uni.         251500000
# 7                           How to Train Your Dragon   P/DW         217600000
# 8  The Chronicles of Narnia: The Voyage of the Da...    Fox         104400000
# 9                                     The Karate Kid   Sony         176600000
#
#    year  averagerating  numvotes  \
# 0  2010            8.3    682218
# 1  2010            8.8   1841066
# 2  2010            6.3    167532
# 3  2010            5.0    211733
# 4  2010            7.0    657690
# 5  2010            7.8    366366
# 6  2010            7.7    464511
# 7  2010            8.1    611299
# 8  2010            6.3    129663
# 9  2010            6.2    146401
#
#                                       original_title start_year  \
# 0                                        Toy Story 3       2010
# 1                                          Inception       2010
# 2                                Shrek Forever After       2010
# 3                         The Twilight Saga: Eclipse       2010
# 4                                         Iron Man 2       2010
# 5                                            Tangled       2010
# 6                                      Despicable Me       2010
# 7                           How to Train Your Dragon       2010
# 8  The Chronicles of Narnia: The Voyage of the Da...       2010
# 9                                     The Karate Kid       2010
#
#    runtime_minutes            directors  \
# 0              103            nm0881279
# 1              148            nm0634240
# 2               93            nm0593610
# 3              124            nm1720541
# 4              124            nm0269463
# 5              100  nm1977355,nm0397174
# 6               95  nm1853544,nm0719208
# 7               98  nm0761498,nm0213450
# 8              113            nm0000776
# 9              140            nm0958969
#
#                                              writers  release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                          nm0634240  Jul 16, 2010
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                nm0742279,nm2769412  Jun 30, 2010
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
# 5                      nm1557594,nm0342278,nm0342303  Nov 24, 2010
# 6                      nm0666791,nm0202425,nm0655053   Jul 9, 2010
# 7  nm0204030,nm0213450,nm0761498,nm2441763,nm0405...  Mar 26, 2010
# 8            nm1321655,nm1321656,nm0678104,nm0507000  Dec 10, 2010
# 9                                nm0614050,nm0436543  Jun 11, 2010
#
#   production_budget domestic_gross_y worldwide_gross
# 0      $200,000,000     $415,004,880  $1,068,879,522
# 1      $160,000,000     $292,576,195    $835,524,642
# 2      $165,000,000     $238,736,787    $756,244,673
# 3       $68,000,000     $300,531,751    $706,102,828
# 4      $170,000,000     $312,433,331    $621,156,389
# 5      $260,000,000     $200,821,936    $586,477,240
# 6       $69,000,000     $251,513,985    $543,464,573
# 7      $165,000,000     $217,581,232    $494,870,992
# 8      $155,000,000     $104,386,950    $418,186,950
# 9       $40,000,000     $176,591,618    $351,774,938

# %%
finalcleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1412
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1413 non-null   object
#  1   studio             1413 non-null   object
#  2   domestic_gross_x   1413 non-null   int32
#  3   year               1413 non-null   int32
#  4   averagerating      1413 non-null   float64
#  5   numvotes           1413 non-null   int64
#  6   original_title     1413 non-null   object
#  7   start_year         1413 non-null   object
#  8   runtime_minutes    1413 non-null   int32
#  9   directors          1413 non-null   object
#  10  writers            1413 non-null   object
#  11  release_date       1413 non-null   object
#  12  production_budget  1413 non-null   object
#  13  domestic_gross_y   1413 non-null   object
#  14  worldwide_gross    1413 non-null   object
# dtypes: float64(1), int32(3), int64(1), object(10)
# memory usage: 160.1+ KB

# %%
finalcleaned_df = finalcleaned_df.drop('domestic_gross_x', axis = 1)

# %%
finalcleaned_df = finalcleaned_df.drop('year', axis = 1)

# %%
finalcleaned_df = finalcleaned_df.drop('start_year', axis = 1)

# %%
finalcleaned_df = finalcleaned_df.drop('original_title', axis = 1)

# %%
finalcleaned_df = finalcleaned_df.rename(columns = {'domestic_gross_y': 'domestic_gross'})

# %%
finalcleaned_df.head(10)
# Out:
#                                                title studio  averagerating  \
# 0                                        Toy Story 3     BV            8.3
# 1                                          Inception     WB            8.8
# 2                                Shrek Forever After   P/DW            6.3
# 3                         The Twilight Saga: Eclipse   Sum.            5.0
# 4                                         Iron Man 2   Par.            7.0
# 5                                            Tangled     BV            7.8
# 6                                      Despicable Me   Uni.            7.7
# 7                           How to Train Your Dragon   P/DW            8.1
# 8  The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                     The Karate Kid   Sony            6.2
#
#    numvotes  runtime_minutes            directors  \
# 0    682218              103            nm0881279
# 1   1841066              148            nm0634240
# 2    167532               93            nm0593610
# 3    211733              124            nm1720541
# 4    657690              124            nm0269463
# 5    366366              100  nm1977355,nm0397174
# 6    464511               95  nm1853544,nm0719208
# 7    611299               98  nm0761498,nm0213450
# 8    129663              113            nm0000776
# 9    146401              140            nm0958969
#
#                                              writers  release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                          nm0634240  Jul 16, 2010
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                nm0742279,nm2769412  Jun 30, 2010
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
# 5                      nm1557594,nm0342278,nm0342303  Nov 24, 2010
# 6                      nm0666791,nm0202425,nm0655053   Jul 9, 2010
# 7  nm0204030,nm0213450,nm0761498,nm2441763,nm0405...  Mar 26, 2010
# 8            nm1321655,nm1321656,nm0678104,nm0507000  Dec 10, 2010
# 9                                nm0614050,nm0436543  Jun 11, 2010
#
#   production_budget domestic_gross worldwide_gross
# 0      $200,000,000   $415,004,880  $1,068,879,522
# 1      $160,000,000   $292,576,195    $835,524,642
# 2      $165,000,000   $238,736,787    $756,244,673
# 3       $68,000,000   $300,531,751    $706,102,828
# 4      $170,000,000   $312,433,331    $621,156,389
# 5      $260,000,000   $200,821,936    $586,477,240
# 6       $69,000,000   $251,513,985    $543,464,573
# 7      $165,000,000   $217,581,232    $494,870,992
# 8      $155,000,000   $104,386,950    $418,186,950
# 9       $40,000,000   $176,591,618    $351,774,938

# %%
finalcleaned_df.isna().any()
# Out:
# title                False
# studio               False
# averagerating        False
# numvotes             False
# runtime_minutes      False
# directors            False
# writers              False
# release_date         False
# production_budget    False
# domestic_gross       False
# worldwide_gross      False
# dtype: bool

# %%
finalcleaned_df.isna().sum()
# Out:
# title                0
# studio               0
# averagerating        0
# numvotes             0
# runtime_minutes      0
# directors            0
# writers              0
# release_date         0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
finalcleaned_df.head(20)
# Out:
#                                                 title studio  averagerating  \
# 0                                         Toy Story 3     BV            8.3
# 1                                           Inception     WB            8.8
# 2                                 Shrek Forever After   P/DW            6.3
# 3                          The Twilight Saga: Eclipse   Sum.            5.0
# 4                                          Iron Man 2   Par.            7.0
# 5                                             Tangled     BV            7.8
# 6                                       Despicable Me   Uni.            7.7
# 7                            How to Train Your Dragon   P/DW            8.1
# 8   The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                      The Karate Kid   Sony            6.2
# 10                                     The Karate Kid   Sony            6.2
# 11                                         Black Swan   FoxS            8.0
# 12                                           Megamind   P/DW            7.3
# 13                                         Robin Hood   Uni.            7.6
# 14                                         Robin Hood   Uni.            7.6
# 15                                         Robin Hood   Uni.            6.3
# 16                                         Robin Hood   Uni.            6.3
# 17                                         Robin Hood   Uni.            5.3
# 18                                         Robin Hood   Uni.            5.3
# 19                                         Robin Hood   Uni.            6.6
#
#     numvotes  runtime_minutes            directors  \
# 0     682218              103            nm0881279
# 1    1841066              148            nm0634240
# 2     167532               93            nm0593610
# 3     211733              124            nm1720541
# 4     657690              124            nm0269463
# 5     366366              100  nm1977355,nm0397174
# 6     464511               95  nm1853544,nm0719208
# 7     611299               98  nm0761498,nm0213450
# 8     129663              113            nm0000776
# 9     146401              140            nm0958969
# 10    146401              140            nm0958969
# 11    648854              108            nm0004716
# 12    207488               95            nm0569891
# 13         5               86            nm7789892
# 14         5               86            nm7789892
# 15        78               92            nm2347483
# 16        78               92            nm2347483
# 17     41588              116            nm1163264
# 18     41588              116            nm1163264
# 19    239480              140            nm0000631
#
#                                               writers  release_date  \
# 0             nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                           nm0634240  Jul 16, 2010
# 2   nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                 nm0742279,nm2769412  Jun 30, 2010
# 4   nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
# 5                       nm1557594,nm0342278,nm0342303  Nov 24, 2010
# 6                       nm0666791,nm0202425,nm0655053   Jul 9, 2010
# 7   nm0204030,nm0213450,nm0761498,nm2441763,nm0405...  Mar 26, 2010
# 8             nm1321655,nm1321656,nm0678104,nm0507000  Dec 10, 2010
# 9                                 nm0614050,nm0436543  Jun 11, 2010
# 10                                nm0614050,nm0436543  Jun 22, 1984
# 11                      nm2114730,nm0374560,nm0572352   Dec 3, 2010
# 12                                nm0774786,nm2523794   Nov 5, 2010
# 13                                                N/A  May 14, 2010
# 14                                                N/A  Nov 21, 2018
# 15                                nm2347483,nm2956784  May 14, 2010
# 16                                nm2347483,nm2956784  Nov 21, 2018
# 17                                nm9808366,nm3598916  May 14, 2010
# 18                                nm9808366,nm3598916  Nov 21, 2018
# 19                      nm0001338,nm0717550,nm0903456  May 14, 2010
#
#    production_budget domestic_gross worldwide_gross
# 0       $200,000,000   $415,004,880  $1,068,879,522
# 1       $160,000,000   $292,576,195    $835,524,642
# 2       $165,000,000   $238,736,787    $756,244,673
# 3        $68,000,000   $300,531,751    $706,102,828
# 4       $170,000,000   $312,433,331    $621,156,389
# 5       $260,000,000   $200,821,936    $586,477,240
# 6        $69,000,000   $251,513,985    $543,464,573
# 7       $165,000,000   $217,581,232    $494,870,992
# 8       $155,000,000   $104,386,950    $418,186,950
# 9        $40,000,000   $176,591,618    $351,774,938
# 10        $8,000,000    $90,815,558     $90,815,558
# 11       $13,000,000   $106,954,678    $331,266,710
# 12      $130,000,000   $148,415,853    $321,887,208
# 13      $210,000,000   $105,487,148    $322,459,006
# 14       $99,000,000    $30,824,628     $84,747,441
# 15      $210,000,000   $105,487,148    $322,459,006
# 16       $99,000,000    $30,824,628     $84,747,441
# 17      $210,000,000   $105,487,148    $322,459,006
# 18       $99,000,000    $30,824,628     $84,747,441
# 19      $210,000,000   $105,487,148    $322,459,006

# %%
finalcleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1412
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1413 non-null   object
#  1   studio             1413 non-null   object
#  2   averagerating      1413 non-null   float64
#  3   numvotes           1413 non-null   int64
#  4   runtime_minutes    1413 non-null   int32
#  5   directors          1413 non-null   object
#  6   writers            1413 non-null   object
#  7   release_date       1413 non-null   object
#  8   production_budget  1413 non-null   object
#  9   domestic_gross     1413 non-null   object
#  10  worldwide_gross    1413 non-null   object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 126.9+ KB

# %%
finalcleaned_df['production_budget'] = finalcleaned_df['production_budget'].map(lambda x: x.lstrip('$').rstrip(''))
finalcleaned_df['domestic_gross'] = finalcleaned_df['domestic_gross'].map(lambda x: x.lstrip('$').rstrip(''))
finalcleaned_df['worldwide_gross'] = finalcleaned_df['worldwide_gross'].map(lambda x: x.lstrip('$').rstrip(''))

# %%
finalcleaned_df['production_budget'].replace(',', '', regex=True, inplace=True)
finalcleaned_df['domestic_gross'].replace(',', '', regex=True, inplace=True)
finalcleaned_df['worldwide_gross'].replace(',', '', regex=True, inplace=True)

# %%
finalcleaned_df.head()
# Out:
#                         title studio  averagerating  numvotes  \
# 0                 Toy Story 3     BV            8.3    682218
# 1                   Inception     WB            8.8   1841066
# 2         Shrek Forever After   P/DW            6.3    167532
# 3  The Twilight Saga: Eclipse   Sum.            5.0    211733
# 4                  Iron Man 2   Par.            7.0    657690
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers  release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                          nm0634240  Jul 16, 2010
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                nm0742279,nm2769412  Jun 30, 2010
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
#
#   production_budget domestic_gross worldwide_gross
# 0         200000000      415004880      1068879522
# 1         160000000      292576195       835524642
# 2         165000000      238736787       756244673
# 3          68000000      300531751       706102828
# 4         170000000      312433331       621156389

# %%
finalcleaned_df = finalcleaned_df.astype({"title": 'object', "studio": 'object', "averagerating": 'float64', "numvotes": 'int64', "runtime_minutes": 'int64', "directors": 'object', "writers": 'object', "release_date": 'string', "production_budget": 'int64',"domestic_gross": 'int64', "worldwide_gross": 'int64'})

# %%
finalcleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1412
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1413 non-null   object
#  1   studio             1413 non-null   object
#  2   averagerating      1413 non-null   float64
#  3   numvotes           1413 non-null   int64
#  4   runtime_minutes    1413 non-null   int64
#  5   directors          1413 non-null   object
#  6   writers            1413 non-null   object
#  7   release_date       1413 non-null   string
#  8   production_budget  1413 non-null   int64
#  9   domestic_gross     1413 non-null   int64
#  10  worldwide_gross    1413 non-null   int64
# dtypes: float64(1), int64(5), object(4), string(1)
# memory usage: 132.5+ KB

# %%
finalcleaned_df.head(15)
# Out:
#                                                 title studio  averagerating  \
# 0                                         Toy Story 3     BV            8.3
# 1                                           Inception     WB            8.8
# 2                                 Shrek Forever After   P/DW            6.3
# 3                          The Twilight Saga: Eclipse   Sum.            5.0
# 4                                          Iron Man 2   Par.            7.0
# 5                                             Tangled     BV            7.8
# 6                                       Despicable Me   Uni.            7.7
# 7                            How to Train Your Dragon   P/DW            8.1
# 8   The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                      The Karate Kid   Sony            6.2
# 10                                     The Karate Kid   Sony            6.2
# 11                                         Black Swan   FoxS            8.0
# 12                                           Megamind   P/DW            7.3
# 13                                         Robin Hood   Uni.            7.6
# 14                                         Robin Hood   Uni.            7.6
#
#     numvotes  runtime_minutes            directors  \
# 0     682218              103            nm0881279
# 1    1841066              148            nm0634240
# 2     167532               93            nm0593610
# 3     211733              124            nm1720541
# 4     657690              124            nm0269463
# 5     366366              100  nm1977355,nm0397174
# 6     464511               95  nm1853544,nm0719208
# 7     611299               98  nm0761498,nm0213450
# 8     129663              113            nm0000776
# 9     146401              140            nm0958969
# 10    146401              140            nm0958969
# 11    648854              108            nm0004716
# 12    207488               95            nm0569891
# 13         5               86            nm7789892
# 14         5               86            nm7789892
#
#                                               writers  release_date  \
# 0             nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                           nm0634240  Jul 16, 2010
# 2   nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                 nm0742279,nm2769412  Jun 30, 2010
# 4   nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
# 5                       nm1557594,nm0342278,nm0342303  Nov 24, 2010
# 6                       nm0666791,nm0202425,nm0655053   Jul 9, 2010
# 7   nm0204030,nm0213450,nm0761498,nm2441763,nm0405...  Mar 26, 2010
# 8             nm1321655,nm1321656,nm0678104,nm0507000  Dec 10, 2010
# 9                                 nm0614050,nm0436543  Jun 11, 2010
# 10                                nm0614050,nm0436543  Jun 22, 1984
# 11                      nm2114730,nm0374560,nm0572352   Dec 3, 2010
# 12                                nm0774786,nm2523794   Nov 5, 2010
# 13                                                N/A  May 14, 2010
# 14                                                N/A  Nov 21, 2018
#
#     production_budget  domestic_gross  worldwide_gross
# 0           200000000       415004880       1068879522
# 1           160000000       292576195        835524642
# 2           165000000       238736787        756244673
# 3            68000000       300531751        706102828
# 4           170000000       312433331        621156389
# 5           260000000       200821936        586477240
# 6            69000000       251513985        543464573
# 7           165000000       217581232        494870992
# 8           155000000       104386950        418186950
# 9            40000000       176591618        351774938
# 10            8000000        90815558         90815558
# 11           13000000       106954678        331266710
# 12          130000000       148415853        321887208
# 13          210000000       105487148        322459006
# 14           99000000        30824628         84747441

# %% [markdown]
# # Data Analysis and Visualizations

# %%
# Question 1: What does the relationship look like between movie budgets and their income? (For those that had profit > 0)
# Question 2: Does the alloted budget have a significant impact on rating score? (For those that had profit > 0)
# Question 3: What seasons averaged the highest gross? (For those that had a profit > 0)

# %% [markdown]
# ### Let's Analyze the data and further develop the information with are looking for in the DF

# %%
finalcleaned_df['domestic_difference'] = finalcleaned_df['domestic_gross'] - finalcleaned_df['production_budget']
finalcleaned_df['worldwide_difference'] = finalcleaned_df['worldwide_gross'] - finalcleaned_df['production_budget']

# %%
finalcleaned_df.head(10)
# Out:
#                                                title studio  averagerating  \
# 0                                        Toy Story 3     BV            8.3
# 1                                          Inception     WB            8.8
# 2                                Shrek Forever After   P/DW            6.3
# 3                         The Twilight Saga: Eclipse   Sum.            5.0
# 4                                         Iron Man 2   Par.            7.0
# 5                                            Tangled     BV            7.8
# 6                                      Despicable Me   Uni.            7.7
# 7                           How to Train Your Dragon   P/DW            8.1
# 8  The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                     The Karate Kid   Sony            6.2
#
#    numvotes  runtime_minutes            directors  \
# 0    682218              103            nm0881279
# 1   1841066              148            nm0634240
# 2    167532               93            nm0593610
# 3    211733              124            nm1720541
# 4    657690              124            nm0269463
# 5    366366              100  nm1977355,nm0397174
# 6    464511               95  nm1853544,nm0719208
# 7    611299               98  nm0761498,nm0213450
# 8    129663              113            nm0000776
# 9    146401              140            nm0958969
#
#                                              writers  release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335  Jun 18, 2010
# 1                                          nm0634240  Jul 16, 2010
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...  May 21, 2010
# 3                                nm0742279,nm2769412  Jun 30, 2010
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   May 7, 2010
# 5                      nm1557594,nm0342278,nm0342303  Nov 24, 2010
# 6                      nm0666791,nm0202425,nm0655053   Jul 9, 2010
# 7  nm0204030,nm0213450,nm0761498,nm2441763,nm0405...  Mar 26, 2010
# 8            nm1321655,nm1321656,nm0678104,nm0507000  Dec 10, 2010
# 9                                nm0614050,nm0436543  Jun 11, 2010
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
# 5          260000000       200821936        586477240            -59178064
# 6           69000000       251513985        543464573            182513985
# 7          165000000       217581232        494870992             52581232
# 8          155000000       104386950        418186950            -50613050
# 9           40000000       176591618        351774938            136591618
#
#    worldwide_difference
# 0             868879522
# 1             675524642
# 2             591244673
# 3             638102828
# 4             451156389
# 5             326477240
# 6             474464573
# 7             329870992
# 8             263186950
# 9             311774938

# %%
finalcleaned_df['release_date'] = pd.to_datetime(finalcleaned_df['release_date'], format='%b %d, %Y')

# %%
finalcleaned_df.head(20)
# Out:
#                                                 title studio  averagerating  \
# 0                                         Toy Story 3     BV            8.3
# 1                                           Inception     WB            8.8
# 2                                 Shrek Forever After   P/DW            6.3
# 3                          The Twilight Saga: Eclipse   Sum.            5.0
# 4                                          Iron Man 2   Par.            7.0
# 5                                             Tangled     BV            7.8
# 6                                       Despicable Me   Uni.            7.7
# 7                            How to Train Your Dragon   P/DW            8.1
# 8   The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                      The Karate Kid   Sony            6.2
# 10                                     The Karate Kid   Sony            6.2
# 11                                         Black Swan   FoxS            8.0
# 12                                           Megamind   P/DW            7.3
# 13                                         Robin Hood   Uni.            7.6
# 14                                         Robin Hood   Uni.            7.6
# 15                                         Robin Hood   Uni.            6.3
# 16                                         Robin Hood   Uni.            6.3
# 17                                         Robin Hood   Uni.            5.3
# 18                                         Robin Hood   Uni.            5.3
# 19                                         Robin Hood   Uni.            6.6
#
#     numvotes  runtime_minutes            directors  \
# 0     682218              103            nm0881279
# 1    1841066              148            nm0634240
# 2     167532               93            nm0593610
# 3     211733              124            nm1720541
# 4     657690              124            nm0269463
# 5     366366              100  nm1977355,nm0397174
# 6     464511               95  nm1853544,nm0719208
# 7     611299               98  nm0761498,nm0213450
# 8     129663              113            nm0000776
# 9     146401              140            nm0958969
# 10    146401              140            nm0958969
# 11    648854              108            nm0004716
# 12    207488               95            nm0569891
# 13         5               86            nm7789892
# 14         5               86            nm7789892
# 15        78               92            nm2347483
# 16        78               92            nm2347483
# 17     41588              116            nm1163264
# 18     41588              116            nm1163264
# 19    239480              140            nm0000631
#
#                                               writers release_date  \
# 0             nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                           nm0634240   2010-07-16
# 2   nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                 nm0742279,nm2769412   2010-06-30
# 4   nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
# 5                       nm1557594,nm0342278,nm0342303   2010-11-24
# 6                       nm0666791,nm0202425,nm0655053   2010-07-09
# 7   nm0204030,nm0213450,nm0761498,nm2441763,nm0405...   2010-03-26
# 8             nm1321655,nm1321656,nm0678104,nm0507000   2010-12-10
# 9                                 nm0614050,nm0436543   2010-06-11
# 10                                nm0614050,nm0436543   1984-06-22
# 11                      nm2114730,nm0374560,nm0572352   2010-12-03
# 12                                nm0774786,nm2523794   2010-11-05
# 13                                                N/A   2010-05-14
# 14                                                N/A   2018-11-21
# 15                                nm2347483,nm2956784   2010-05-14
# 16                                nm2347483,nm2956784   2018-11-21
# 17                                nm9808366,nm3598916   2010-05-14
# 18                                nm9808366,nm3598916   2018-11-21
# 19                      nm0001338,nm0717550,nm0903456   2010-05-14
#
#     production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0           200000000       415004880       1068879522            215004880
# 1           160000000       292576195        835524642            132576195
# 2           165000000       238736787        756244673             73736787
# 3            68000000       300531751        706102828            232531751
# 4           170000000       312433331        621156389            142433331
# 5           260000000       200821936        586477240            -59178064
# 6            69000000       251513985        543464573            182513985
# 7           165000000       217581232        494870992             52581232
# 8           155000000       104386950        418186950            -50613050
# 9            40000000       176591618        351774938            136591618
# 10            8000000        90815558         90815558             82815558
# 11           13000000       106954678        331266710             93954678
# 12          130000000       148415853        321887208             18415853
# 13          210000000       105487148        322459006           -104512852
# 14           99000000        30824628         84747441            -68175372
# 15          210000000       105487148        322459006           -104512852
# 16           99000000        30824628         84747441            -68175372
# 17          210000000       105487148        322459006           -104512852
# 18           99000000        30824628         84747441            -68175372
# 19          210000000       105487148        322459006           -104512852
#
#     worldwide_difference
# 0              868879522
# 1              675524642
# 2              591244673
# 3              638102828
# 4              451156389
# 5              326477240
# 6              474464573
# 7              329870992
# 8              263186950
# 9              311774938
# 10              82815558
# 11             318266710
# 12             191887208
# 13             112459006
# 14             -14252559
# 15             112459006
# 16             -14252559
# 17             112459006
# 18             -14252559
# 19             112459006

# %%
finalcleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1412
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 1413 non-null   object
#  1   studio                1413 non-null   object
#  2   averagerating         1413 non-null   float64
#  3   numvotes              1413 non-null   int64
#  4   runtime_minutes       1413 non-null   int64
#  5   directors             1413 non-null   object
#  6   writers               1413 non-null   object
#  7   release_date          1413 non-null   datetime64[ns]
#  8   production_budget     1413 non-null   int64
#  9   domestic_gross        1413 non-null   int64
#  10  worldwide_gross       1413 non-null   int64
#  11  domestic_difference   1413 non-null   int64
#  12  worldwide_difference  1413 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(4)
# memory usage: 154.5+ KB

# %% [markdown]
# ### Ok With All Data Needed Properly Formatted + Organized... Time to Graph

# %%
# Initial Graphs

# %%
finalcleaned_df['domestic_difference'].describe()
# Out:
# count    1.413000e+03
# mean     1.383999e+07
# std      6.060979e+07
# min     -2.019413e+08
# 25%     -1.134288e+07
# 50%     -5.445900e+04
# 75%      2.681666e+07
# max      5.000596e+08
# Name: domestic_difference, dtype: float64

# %%
finalcleaned_df['worldwide_difference'].describe()
# Out:
# count    1.413000e+03
# mean     1.040634e+08
# std      1.931573e+08
# min     -1.104502e+08
# 25%      1.525973e+06
# 50%      3.115860e+07
# 75%      1.191555e+08
# max      1.748134e+09
# Name: worldwide_difference, dtype: float64

# %%
x = finalcleaned_df['production_budget']
y = finalcleaned_df['domestic_difference']

plt.figure(figsize = (20, 10))
plt.scatter(x, y, c=y, cmap = 'plasma')
plt.axvline(0, c = 'black')
plt.axhline(0, c = 'black')

plt.xlabel("Production Budget", fontsize = 20, color = "black")
plt.ylabel("Domestic Difference", fontsize = 20, color = "black")
plt.title("Domestic Profit vs. Budget", fontsize = 30, color = "black")

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.colorbar()
plt.show()

# %%
x = finalcleaned_df['production_budget']
y = finalcleaned_df['worldwide_difference']

plt.figure(figsize = (20, 10))
plt.scatter(x, y, c=y, cmap = 'plasma')
plt.axvline(0, c = 'black')
plt.axhline(0, c = 'black')

plt.xlabel("Production Budget", fontsize = 20, color = "black")
plt.ylabel("Worldwide Difference", fontsize = 20, color = "black")
plt.title("World Wide Profit vs. Budget", fontsize = 30, color = "black")

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.colorbar()
plt.show()

# %%
x = finalcleaned_df['production_budget']
y = finalcleaned_df['averagerating']

plt.figure(figsize = (20, 10))
plt.scatter(x, y, c=y, cmap = 'plasma')
plt.axvline(0, c = 'black')
plt.axhline(0, c = 'black')

plt.xlabel("Production Budget", fontsize = 20, color = "black")
plt.ylabel("Average Rating", fontsize = 20, color = "black")
plt.title("Rating vs. Budget", fontsize = 30, color = "black")

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.colorbar()
plt.show()

# %%
finalcleaned_df.head(10)
# Out:
#                                                title studio  averagerating  \
# 0                                        Toy Story 3     BV            8.3
# 1                                          Inception     WB            8.8
# 2                                Shrek Forever After   P/DW            6.3
# 3                         The Twilight Saga: Eclipse   Sum.            5.0
# 4                                         Iron Man 2   Par.            7.0
# 5                                            Tangled     BV            7.8
# 6                                      Despicable Me   Uni.            7.7
# 7                           How to Train Your Dragon   P/DW            8.1
# 8  The Chronicles of Narnia: The Voyage of the Da...    Fox            6.3
# 9                                     The Karate Kid   Sony            6.2
#
#    numvotes  runtime_minutes            directors  \
# 0    682218              103            nm0881279
# 1   1841066              148            nm0634240
# 2    167532               93            nm0593610
# 3    211733              124            nm1720541
# 4    657690              124            nm0269463
# 5    366366              100  nm1977355,nm0397174
# 6    464511               95  nm1853544,nm0719208
# 7    611299               98  nm0761498,nm0213450
# 8    129663              113            nm0000776
# 9    146401              140            nm0958969
#
#                                              writers release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                          nm0634240   2010-07-16
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                nm0742279,nm2769412   2010-06-30
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
# 5                      nm1557594,nm0342278,nm0342303   2010-11-24
# 6                      nm0666791,nm0202425,nm0655053   2010-07-09
# 7  nm0204030,nm0213450,nm0761498,nm2441763,nm0405...   2010-03-26
# 8            nm1321655,nm1321656,nm0678104,nm0507000   2010-12-10
# 9                                nm0614050,nm0436543   2010-06-11
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
# 5          260000000       200821936        586477240            -59178064
# 6           69000000       251513985        543464573            182513985
# 7          165000000       217581232        494870992             52581232
# 8          155000000       104386950        418186950            -50613050
# 9           40000000       176591618        351774938            136591618
#
#    worldwide_difference
# 0             868879522
# 1             675524642
# 2             591244673
# 3             638102828
# 4             451156389
# 5             326477240
# 6             474464573
# 7             329870992
# 8             263186950
# 9             311774938

# %%
finalcleaned_df['month'] = finalcleaned_df['release_date'].dt.strftime('%b')

# %%
finalcleaned_df.head()
# Out:
#                         title studio  averagerating  numvotes  \
# 0                 Toy Story 3     BV            8.3    682218
# 1                   Inception     WB            8.8   1841066
# 2         Shrek Forever After   P/DW            6.3    167532
# 3  The Twilight Saga: Eclipse   Sum.            5.0    211733
# 4                  Iron Man 2   Par.            7.0    657690
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                          nm0634240   2010-07-16
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                nm0742279,nm2769412   2010-06-30
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
#
#    worldwide_difference month
# 0             868879522   Jun
# 1             675524642   Jul
# 2             591244673   May
# 3             638102828   Jun
# 4             451156389   May

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.boxplot(x='month',y='domestic_difference',data=finalcleaned_df,ax=ax).set_title("Domestic Profit vs. Month of Year")

plt.xlabel("Month of Year", fontsize = 20, color = "black")
plt.ylabel("Domestic Profit", fontsize = 20, color = "black")
plt.title("Domestic Profit vs. Month of Year", fontsize = 30, color = "black")

plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.boxplot(x='month',y='worldwide_difference',data=finalcleaned_df,ax=ax).set_title("Worldwide Profit vs. Month of Year")

plt.xlabel("Month of Year", fontsize = 20, color = "black")
plt.ylabel("Worldwide Profit", fontsize = 20, color = "black")
plt.title("Worldwide Profit vs. Month of Year", fontsize = 30, color = "black")


plt.show()

# %% [markdown]
# # With Visualizations Completed, Time to Confirm Findings

# %%
finalcleaned_df.groupby('month', as_index=True)['domestic_gross'].mean()
# Out:
# month
# Apr    4.579376e+07
# Aug    4.501349e+07
# Dec    6.737212e+07
# Feb    6.048584e+07
# Jan    4.145290e+07
# Jul    7.826111e+07
# Jun    1.002354e+08
# Mar    5.200844e+07
# May    8.554047e+07
# Nov    7.470179e+07
# Oct    3.395967e+07
# Sep    3.290262e+07
# Name: domestic_gross, dtype: float64

# %%
# May has the highest average domestic gross income

# %%
finalcleaned_df.groupby('month', as_index=True)['worldwide_gross'].mean()
# Out:
# month
# Apr    1.263916e+08
# Aug    9.609669e+07
# Dec    1.622217e+08
# Feb    1.417541e+08
# Jan    8.849601e+07
# Jul    2.098260e+08
# Jun    2.476531e+08
# Mar    1.242663e+08
# May    2.317882e+08
# Nov    1.995040e+08
# Oct    8.869919e+07
# Sep    7.435284e+07
# Name: worldwide_gross, dtype: float64

# %%
# August has the highest average worldwide gross income

# %%
finalcleaned_df.groupby('month', as_index=True)['domestic_difference'].mean()
# Out:
# month
# Apr    1.313363e+07
# Aug    1.018117e+07
# Dec    1.905489e+07
# Feb    1.375352e+07
# Jan    1.402617e+07
# Jul    2.192543e+07
# Jun    3.530755e+07
# Mar    3.047722e+06
# May    8.152970e+06
# Nov    1.585212e+07
# Oct    3.047366e+06
# Sep    5.176227e+06
# Name: domestic_difference, dtype: float64

# %%
# May has the highest difference

# %%
finalcleaned_df.groupby('month', as_index=True)['worldwide_difference'].mean()
# Out:
# month
# Apr    9.373143e+07
# Aug    6.126437e+07
# Dec    1.139045e+08
# Feb    9.502177e+07
# Jan    6.106928e+07
# Jul    1.534903e+08
# Jun    1.827252e+08
# Mar    7.530562e+07
# May    1.544007e+08
# Nov    1.406543e+08
# Oct    5.778688e+07
# Sep    4.662645e+07
# Name: worldwide_difference, dtype: float64

# %%
# Feb has the highest difference

# %%
finalcleaned_df['int_ar'] = finalcleaned_df['averagerating'].astype(int)

# %%
finalcleaned_df.head()
# Out:
#                         title studio  averagerating  numvotes  \
# 0                 Toy Story 3     BV            8.3    682218
# 1                   Inception     WB            8.8   1841066
# 2         Shrek Forever After   P/DW            6.3    167532
# 3  The Twilight Saga: Eclipse   Sum.            5.0    211733
# 4                  Iron Man 2   Par.            7.0    657690
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                          nm0634240   2010-07-16
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                nm0742279,nm2769412   2010-06-30
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
#
#    worldwide_difference month  int_ar
# 0             868879522   Jun       8
# 1             675524642   Jul       8
# 2             591244673   May       6
# 3             638102828   Jun       5
# 4             451156389   May       7

# %%
finalcleaned_df.groupby('int_ar', as_index=True)['domestic_difference'].mean()
# Out:
# int_ar
# 1    2.930267e+07
# 2    4.431218e+07
# 3    1.111837e+07
# 4    9.821580e+06
# 5   -2.751099e+06
# 6    6.689148e+06
# 7    3.061533e+07
# 8    4.524509e+07
# 9   -3.561632e+06
# Name: domestic_difference, dtype: float64

# %%
finalcleaned_df.groupby('int_ar', as_index=True)['worldwide_difference'].mean()
# Out:
# int_ar
# 1    4.544898e+07
# 2    1.482497e+08
# 3    4.871673e+07
# 4    7.150578e+07
# 5    5.604755e+07
# 6    8.617372e+07
# 7    1.491513e+08
# 8    2.398932e+08
# 9   -1.363053e+06
# Name: worldwide_difference, dtype: float64

# %%
# It seems movies with an average rating of 4 had the highest average of domestic profit
# It seems movies with an average rating of 6 had the highest average of worldwide profit

# Keep in mind the difference of number of movies in for each rating

# %% [markdown]
# ## Creation of New Data Frames and Graphs for a Different Look / Understanding

# %%
dom_pos_diff_df = finalcleaned_df[finalcleaned_df['domestic_difference'] > 0]

# %%
ww_pos_diff_df = finalcleaned_df[finalcleaned_df['worldwide_difference'] > 0]

# %% [markdown]
# dom_pos_diff_df.head()

# %%
dom_pos_diff_df.head()
# Out:
#                         title studio  averagerating  numvotes  \
# 0                 Toy Story 3     BV            8.3    682218
# 1                   Inception     WB            8.8   1841066
# 2         Shrek Forever After   P/DW            6.3    167532
# 3  The Twilight Saga: Eclipse   Sum.            5.0    211733
# 4                  Iron Man 2   Par.            7.0    657690
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                          nm0634240   2010-07-16
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                nm0742279,nm2769412   2010-06-30
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
#
#    worldwide_difference month  int_ar
# 0             868879522   Jun       8
# 1             675524642   Jul       8
# 2             591244673   May       6
# 3             638102828   Jun       5
# 4             451156389   May       7

# %%
dom_pos_diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 706 entries, 0 to 1398
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 706 non-null    object
#  1   studio                706 non-null    object
#  2   averagerating         706 non-null    float64
#  3   numvotes              706 non-null    int64
#  4   runtime_minutes       706 non-null    int64
#  5   directors             706 non-null    object
#  6   writers               706 non-null    object
#  7   release_date          706 non-null    datetime64[ns]
#  8   production_budget     706 non-null    int64
#  9   domestic_gross        706 non-null    int64
#  10  worldwide_gross       706 non-null    int64
#  11  domestic_difference   706 non-null    int64
#  12  worldwide_difference  706 non-null    int64
#  13  month                 706 non-null    object
#  14  int_ar                706 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(7), object(5)
# memory usage: 85.5+ KB

# %%
ww_pos_diff_df.head()
# Out:
#                         title studio  averagerating  numvotes  \
# 0                 Toy Story 3     BV            8.3    682218
# 1                   Inception     WB            8.8   1841066
# 2         Shrek Forever After   P/DW            6.3    167532
# 3  The Twilight Saga: Eclipse   Sum.            5.0    211733
# 4                  Iron Man 2   Par.            7.0    657690
#
#    runtime_minutes  directors  \
# 0              103  nm0881279
# 1              148  nm0634240
# 2               93  nm0593610
# 3              124  nm1720541
# 4              124  nm0269463
#
#                                              writers release_date  \
# 0            nm0005124,nm0004056,nm0881279,nm1578335   2010-06-18
# 1                                          nm0634240   2010-07-16
# 2  nm0825308,nm0458441,nm0501359,nm0011470,nm0254...   2010-05-21
# 3                                nm0742279,nm2769412   2010-06-30
# 4  nm0857620,nm0498278,nm1411347,nm1293367,nm0456158   2010-05-07
#
#    production_budget  domestic_gross  worldwide_gross  domestic_difference  \
# 0          200000000       415004880       1068879522            215004880
# 1          160000000       292576195        835524642            132576195
# 2          165000000       238736787        756244673             73736787
# 3           68000000       300531751        706102828            232531751
# 4          170000000       312433331        621156389            142433331
#
#    worldwide_difference month  int_ar
# 0             868879522   Jun       8
# 1             675524642   Jul       8
# 2             591244673   May       6
# 3             638102828   Jun       5
# 4             451156389   May       7

# %%
ww_pos_diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1096 entries, 0 to 1404
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 1096 non-null   object
#  1   studio                1096 non-null   object
#  2   averagerating         1096 non-null   float64
#  3   numvotes              1096 non-null   int64
#  4   runtime_minutes       1096 non-null   int64
#  5   directors             1096 non-null   object
#  6   writers               1096 non-null   object
#  7   release_date          1096 non-null   datetime64[ns]
#  8   production_budget     1096 non-null   int64
#  9   domestic_gross        1096 non-null   int64
#  10  worldwide_gross       1096 non-null   int64
#  11  domestic_difference   1096 non-null   int64
#  12  worldwide_difference  1096 non-null   int64
#  13  month                 1096 non-null   object
#  14  int_ar                1096 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(7), object(5)
# memory usage: 132.7+ KB

# %%
x = dom_pos_diff_df['production_budget']
y = dom_pos_diff_df['domestic_difference']

plt.figure(figsize = (20, 10))
plt.scatter(x, y, c=y, cmap = 'plasma')
plt.axvline(0, c = 'black')
plt.axhline(0, c = 'black')

plt.xlabel("Production Budget", fontsize = 20, color = "black")
plt.ylabel("Domestic Difference", fontsize = 20, color = "black")
plt.title("Positive Domestic Profit vs. Budget", fontsize = 30, color = "black")

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.colorbar()
plt.show()

# %%
x = ww_pos_diff_df['production_budget']
y = ww_pos_diff_df['worldwide_difference']

plt.figure(figsize = (20, 10))
plt.scatter(x, y, c=y, cmap = 'plasma')
plt.axvline(0, c = 'black')
plt.axhline(0, c = 'black')

plt.xlabel("Production Budget", fontsize = 20, color = "black")
plt.ylabel("Worldwide Difference", fontsize = 20, color = "black")
plt.title("Positive Worldwide Profit vs. Budget", fontsize = 30, color = "black")

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.barplot(x="int_ar", y="domestic_difference", data=dom_pos_diff_df, ci="sd").set_title("Positive Domestic Profit vs. Average Rating")

plt.xlabel("Average Rating", fontsize = 20, color = "black")
plt.ylabel("Positive Domestic Profit", fontsize = 20, color = "black")
plt.title("Positive Domestic Profit vs. Average Rating", fontsize = 30, color = "black")

plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.barplot(x="int_ar", y="worldwide_difference", data=ww_pos_diff_df, ci="sd").set_title("Positive Worldwide Profit vs. Average Rating")

plt.xlabel("Average Rating", fontsize = 20, color = "black")
plt.ylabel("Positive Worldwide Profit", fontsize = 20, color = "black")
plt.title("Positive Worldwide Profit vs. Average Rating", fontsize = 30, color = "black")

plt.show()

# %%
dom_pos_diff_df.groupby('month', as_index=True)['domestic_difference'].mean()
# Out:
# month
# Apr    4.037548e+07
# Aug    3.690016e+07
# Dec    5.178366e+07
# Feb    5.459813e+07
# Jan    4.115104e+07
# Jul    5.629612e+07
# Jun    8.645974e+07
# Mar    3.836554e+07
# May    4.922720e+07
# Nov    5.144501e+07
# Oct    3.320405e+07
# Sep    3.035262e+07
# Name: domestic_difference, dtype: float64

# %%
ww_pos_diff_df.groupby('month', as_index=True)['domestic_difference'].mean()
# Out:
# month
# Apr    2.149990e+07
# Aug    1.528388e+07
# Dec    2.782387e+07
# Feb    2.522352e+07
# Jan    2.418295e+07
# Jul    3.103105e+07
# Jun    5.112981e+07
# Mar    1.383434e+07
# May    1.335255e+07
# Nov    2.413705e+07
# Oct    9.735281e+06
# Sep    1.445359e+07
# Name: domestic_difference, dtype: float64

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.boxplot(x='month',y='domestic_difference',data=dom_pos_diff_df,ax=ax).set_title("Positive Domestic Profit vs. Month of Year")

plt.xlabel("Month of Year", fontsize = 20, color = "black")
plt.ylabel("Positive Domestic Profit", fontsize = 20, color = "black")
plt.title("Positive Domestic Profit vs. Average Rating", fontsize = 30, color = "black")

plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches((20,10))
sns.boxplot(x='month',y='worldwide_difference',data=ww_pos_diff_df,ax=ax).set_title("Positive Worldwide Profit vs. Month of Year")

plt.xlabel("Month of Year", fontsize = 20, color = "black")
plt.ylabel("Positive Worldwide Profit", fontsize = 20, color = "black")
plt.title("Positive Worldwide Profit vs. Average Rating", fontsize = 30, color = "black")

plt.show()

# %%
dom_pos_diff_df.groupby('month', as_index=True)['domestic_difference'].mean()
# Out:
# month
# Apr    4.037548e+07
# Aug    3.690016e+07
# Dec    5.178366e+07
# Feb    5.459813e+07
# Jan    4.115104e+07
# Jul    5.629612e+07
# Jun    8.645974e+07
# Mar    3.836554e+07
# May    4.922720e+07
# Nov    5.144501e+07
# Oct    3.320405e+07
# Sep    3.035262e+07
# Name: domestic_difference, dtype: float64

# %%
ww_pos_diff_df.groupby('month', as_index=True)['worldwide_difference'].mean()
# Out:
# month
# Apr    1.293251e+08
# Aug    7.745949e+07
# Dec    1.394131e+08
# Feb    1.213736e+08
# Jan    8.268804e+07
# Jul    1.886464e+08
# Jun    2.475511e+08
# Mar    1.112896e+08
# May    1.872412e+08
# Nov    1.722788e+08
# Oct    8.469473e+07
# Sep    7.134185e+07
# Name: worldwide_difference, dtype: float64

# %% [markdown]
# # All Graphs and Information Needed Completed!

# %%
# Time to wrap things up!!!

# Realized I was working on the dsc repo and should have started with the creation of the repo for this project first...
# I believe I have properly converted / transferred all files to my repo for this project
